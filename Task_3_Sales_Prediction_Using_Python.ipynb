# %% [markdown]
# **SALES PREDICTION USING PYTHON**

# %% [markdown]
# **Import Required Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the dataset**

# %%
data=pd.read_csv("/content/sample_data/advertising.csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.head(10)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
# 5    8.7   48.9       75.0    7.2
# 6   57.5   32.8       23.5   11.8
# 7  120.2   19.6       11.6   13.2
# 8    8.6    2.1        1.0    4.8
# 9  199.8    2.6       21.2   15.6

# %%
data.tail(10)
# Out:
#         TV  Radio  Newspaper  Sales
# 190   39.5   41.1        5.8   10.8
# 191   75.5   10.8        6.0   11.9
# 192   17.2    4.1       31.6    5.9
# 193  166.8   42.0        3.6   19.6
# 194  149.7   35.6        6.0   17.3
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
data.count()
# Out:
# TV           200
# Radio        200
# Newspaper    200
# Sales        200
# dtype: int64

# %%
data.value_counts("TV")
# Out:
# TV
# 109.8    2
# 177.0    2
# 240.1    2
# 76.4     2
# 222.4    2
#         ..
# 97.2     1
# 97.5     1
# 100.4    1
# 102.7    1
# 296.4    1
# Length: 190, dtype: int64

# %%
data.value_counts("Radio")
# Out:
# Radio
# 4.1     3
# 5.7     3
# 18.1    2
# 43.9    2
# 4.9     2
#        ..
# 17.4    1
# 19.2    1
# 19.6    1
# 20.0    1
# 49.6    1
# Length: 167, dtype: int64

# %%
data.value_counts("Newspaper")
# Out:
# Newspaper
# 25.6     3
# 8.7      3
# 9.3      3
# 31.6     2
# 22.9     2
#         ..
# 19.6     1
# 20.3     1
# 20.5     1
# 20.6     1
# 114.0    1
# Length: 172, dtype: int64

# %%
data.value_counts('Sales')
# Out:
# Sales
# 11.9    5
# 16.7    5
# 20.7    4
# 16.0    3
# 20.9    3
#        ..
# 13.3    1
# 12.5    1
# 12.4    1
# 12.3    1
# 27.0    1
# Length: 121, dtype: int64

# %%
data.shape
# Out:
# (200, 4)

# %%
print('Number of Rows:',data.shape[0])
print(' Number of Columns:',data.shape[1])
# Out:
# Number of Rows: 200
#  Number of Columns: 4

# %%
data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
print("Average Sales:",data['Sales'].mean())
# Out:
# Average Sales: 15.130500000000001

# %%
data['Sales'].std()
# Out:
# 5.283892252561876

# %%
data['Sales'].var()
# Out:
# 27.919517336683416

# %%
data['TV'].min()
# Out:
# 0.7

# %%
data['Newspaper'].max()
# Out:
# 114.0

# %%
data.nunique()
# Out:
# TV           190
# Radio        167
# Newspaper    172
# Sales        121
# dtype: int64

# %%
data['Sales'].unique()
# Out:
# array([22.1, 10.4, 12. , 16.5, 17.9,  7.2, 11.8, 13.2,  4.8, 15.6, 12.6,
#        17.4,  9.2, 13.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. , 17.5,
#         5.6, 20.5,  9.7, 17. , 15. , 20.9, 18.9, 10.5, 21.4, 11.9, 17.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 16.1, 10.6, 23.2,
#        19.8, 16.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1,
#        24.2, 14. , 16. , 11. , 13.4, 22.3, 18.3, 12.4,  8.8,  8.7,  6.9,
#        14.2,  5.3, 17.3, 13.6, 21.7, 12.9, 16.7,  7.3, 19.4, 22.2, 11.5,
#        16.9, 17.2, 19.7, 21.8, 12.2,  9.4, 15.9,  6.6, 15.5,  7. , 15.2,
#        24.7,  1.6, 17.7,  5.7, 19.6, 10.8, 11.6,  9.5, 20.8,  9.6, 10.9,
#        19.2, 20.1, 12.3, 10.3, 18.2, 20.6,  3.2, 15.3, 13.3, 19.9,  8. ,
#        20. ,  8.4,  7.6, 27. , 16.8, 17.6, 26.2,  6.7,  5.9, 14.8, 25.5])

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# **Cleaning the dataset**

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.drop_duplicates('Sales')
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 183  287.6   43.0       71.8   26.2
# 189   18.7   12.1       23.4    6.7
# 192   17.2    4.1       31.6    5.9
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
#
# [121 rows x 4 columns]

# %%
Q1=data['Sales'].quantile(0.25)
Q3=data['Sales'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
Outliers=data[(data['Sales']<lower_bound)| (data['Sales']>upper_bound)]
print(Outliers)
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Newspaper, Sales]
# Index: []

# %% [markdown]
# **Data Visualizations**

# %%
plt.hist(x=data['TV'],bins=20,color='c',edgecolor='k')
plt.xlabel("TV")
plt.ylabel("Frequency")
plt.title("Distribution of TV")
plt.show()

# %%
plt.hist(x=data['Radio'],bins=20,color='pink',edgecolor='k')
plt.xlabel("Radio")
plt.ylabel("Frequency")
plt.title("Distribution of Radio")
plt.show()

# %%
plt.hist(x=data['Newspaper'],bins=20,color='plum',edgecolor='k')
plt.xlabel("Newspaper")
plt.ylabel("Frequency")
plt.title("Distribution of Newspaper")
plt.show()

# %%
plt.hist(x=data['Sales'],bins= 20,color='c',edgecolor='k')
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.title("Distribution of Sales")
plt.show()

# %%
sns.boxplot(x=data['Sales'])
plt.xlabel("Sales")
plt.title("Box Plot of Sales")
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
correlation=data.corr()
print(correlation)
sns.heatmap(correlation,annot=True,cmap='Pastel1')
plt.show()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
plt.scatter(data['TV'],data['Sales'],c='b',label='TV')
plt.scatter(data['Radio'],data['Sales'],c='g',label='Radio')
plt.scatter(data['Newspaper'],data['Sales'],c='r',label='Newspaper')
plt.xlabel("Advertising Expenditure")
plt.ylabel("Sales")
plt.legend()
plt.title("Adversting Expenditure Vs Sales")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
x=data[['TV','Radio','Newspaper']]
y=data['Sales']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
lin=LinearRegression()
lin.fit(x_train,y_train)
lin_pre=lin.predict(x_test)
mse=mean_squared_error(y_test,lin_pre)
r2=r2_score(y_test,lin_pre)
print("Linear Regression:",mse)
print("R-Squared:",r2)
# Out:
# Linear Regression: 2.9077569102710896
# R-Squared: 0.9059011844150826

# %%
print(lin_pre)
# Out:
# [17.0347724  20.40974033 23.72398873  9.27278518 21.68271879 12.56940161
#  21.08119452  8.69035045 17.23701254 16.66657475  8.92396497  8.4817344
#  18.2075123   8.06750728 12.64550975 14.93162809  8.12814594 17.89876565
#  11.00880637 20.47832788 20.80631846 12.59883297 10.9051829  22.38854775
#   9.41796094  7.92506736 20.83908497 13.81520938 10.77080925  7.92682509
#  15.95947357 10.63490851 20.80292008 10.43434164 21.5784752  21.18364487
#  12.12821771 22.80953262 12.60992766  6.46441252]

# %%
lin.coef_
# Out:
# array([0.05450927, 0.10094536, 0.00433665])

# %%
lin.intercept_
# Out:
# 4.714126402214127

# %%
plt.plot(lin_pre)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig=plt.figure(figsize=(20,5))
ax=fig.add_subplot(111,projection='3d')
scatter=ax.scatter(data['TV'],data['Radio'],data['Newspaper'],c=data['Sales'],marker='o')
ax.set_xlabel("TV")
ax.set_ylabel("Radio")
ax.set_zlabel("Newspaper")
ax.set_title("Three dimensional Scatter Plot")
colorbar=plt.colorbar(scatter,ax=ax,label='Sales')
plt.show()
